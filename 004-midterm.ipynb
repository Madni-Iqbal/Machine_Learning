# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"D:\AI\008_NED_Machine_Learning\data\018-Student Depression Dataset.csv")
df.head()
# Out:
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                  5
# 1   8  Female  24.0      Bangalore    Student                  2
# 2  26    Male  31.0       Srinagar    Student                  3
# 3  30  Female  28.0       Varanasi    Student                  3
# 4  32  Female  25.0         Jaipur    Student                  4
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0              0  8.97                   2                 0
# 1              0  5.90                   5                 0
# 2              0  7.03                   5                 0
# 3              0  5.59                   2                 0
# 4              0  8.13                   3                 0
#
#       Sleep Duration Dietary Habits   Degree  \
# 0          5-6 hours        Healthy  B.Pharm
# 1          5-6 hours       Moderate      BSc
# 2  Less than 5 hours        Healthy       BA
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27901 entries, 0 to 27900
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     27901 non-null  int64
#  1   Gender                                 27896 non-null  object
#  2   Age                                    27893 non-null  float64
#  3   City                                   27900 non-null  object
#  4   Profession                             27901 non-null  object
#  5   Academic Pressure                      27901 non-null  int64
#  6   Work Pressure                          27901 non-null  int64
#  7   CGPA                                   27901 non-null  float64
#  8   Study Satisfaction                     27901 non-null  int64
#  9   Job Satisfaction                       27901 non-null  int64
# ...

# %%
df.columns
# Out:
# Index(['id', 'Gender', 'Age', 'City', 'Profession', 'Academic Pressure',
#        'Work Pressure', 'CGPA', 'Study Satisfaction', 'Job Satisfaction',
#        'Sleep Duration', 'Dietary Habits', 'Degree',
#        'Have you ever had suicidal thoughts ?', 'Work/Study Hours',
#        'Financial Stress', 'Family History of Mental Illness', 'Depression'],
#       dtype='object')

# %%
df['Depression'].count()
# Out:
# 27901

# %%
df['Depression'].value_counts()
# Out:
# Depression
# 1    16336
# 0    11565
# Name: count, dtype: int64

# %%
df[['Depression']]
# Out:
#        Depression
# 0               1
# 1               0
# 2               0
# 3               1
# 4               0
# ...           ...
# 27896           0
# 27897           0
# 27898           0
# 27899           1
# 27900           1
#
# [27901 rows x 1 columns]

# %%
df.isnull().sum()
# Out:
# id                                       0
# Gender                                   5
# Age                                      8
# City                                     1
# Profession                               0
# Academic Pressure                        0
# Work Pressure                            0
# CGPA                                     0
# Study Satisfaction                       0
# Job Satisfaction                         0
# Sleep Duration                           5
# Dietary Habits                           0
# Degree                                   4
# Have you ever had suicidal thoughts ?    0
# Work/Study Hours                         3
# Financial Stress                         3
# Family History of Mental Illness         4
# Depression                               0
# dtype: int64

# %%
df.describe()
# Out:
#                   id           Age  Academic Pressure  Work Pressure  \
# count   27901.000000  27893.000000       27901.000000   27901.000000
# mean    70442.149421     25.822500           3.141214       0.000430
# std     40641.175216      4.905979           1.381465       0.043992
# min         2.000000     18.000000           0.000000       0.000000
# 25%     35039.000000     21.000000           2.000000       0.000000
# 50%     70684.000000     25.000000           3.000000       0.000000
# 75%    105818.000000     30.000000           4.000000       0.000000
# max    140699.000000     59.000000           5.000000       5.000000
#
#                CGPA  Study Satisfaction  Job Satisfaction  Work/Study Hours  \
# count  27901.000000        27901.000000      27901.000000      27898.000000
# mean       7.656104            2.943837          0.000681          7.157036
# std        1.470707            1.361148          0.044394          3.707748
# ...

# %%
df.shape
# Out:
# (27901, 18)

# %%
df.describe(include='object')
# Out:
#        Gender    City Profession     Sleep Duration Dietary Habits    Degree  \
# count   27896   27900      27901              27896          27901     27897
# unique      2      52         14                  5              4        28
# top      Male  Kalyan    Student  Less than 5 hours      Unhealthy  Class 12
# freq    15543    1570      27870               8306          10317      6078
#
#        Have you ever had suicidal thoughts ? Family History of Mental Illness
# count                                  27901                            27897
# unique                                     2                                2
# top                                      Yes                               No
# freq                                   17656                            14397

# %%
df.isnull().sum()
# Out:
# id                                       0
# Gender                                   5
# Age                                      8
# City                                     1
# Profession                               0
# Academic Pressure                        0
# Work Pressure                            0
# CGPA                                     0
# Study Satisfaction                       0
# Job Satisfaction                         0
# Sleep Duration                           5
# Dietary Habits                           0
# Degree                                   4
# Have you ever had suicidal thoughts ?    0
# Work/Study Hours                         3
# Financial Stress                         3
# Family History of Mental Illness         4
# Depression                               0
# dtype: int64

# %%
df['Gender'].mode()[0]
# Out:
# 'Male'

# %%
df['Gender']=df['Gender'].fillna(df['Gender'].mode()[0])
df['City']=df['City'].fillna(df['City'].mode()[0])
df['Sleep Duration']=df['Sleep Duration'].fillna(df['Sleep Duration'].mode()[0])
df['Degree']=df['Degree'].fillna(df['Degree'].mode()[0])
df['Family History of Mental Illness']=df['Family History of Mental Illness'].fillna(df['Family History of Mental Illness'].mode()[0])

# %%
df['Age']=df['Age'].fillna(df['Age'].mean())
df['Work/Study Hours']=df['Work/Study Hours'].fillna(df['Work/Study Hours'].mean())
df['Financial Stress']=df['Financial Stress'].fillna(df['Financial Stress'].median())

# %%
df.isnull().sum()
# Out:
# id                                       0
# Gender                                   0
# Age                                      0
# City                                     0
# Profession                               0
# Academic Pressure                        0
# Work Pressure                            0
# CGPA                                     0
# Study Satisfaction                       0
# Job Satisfaction                         0
# Sleep Duration                           0
# Dietary Habits                           0
# Degree                                   0
# Have you ever had suicidal thoughts ?    0
# Work/Study Hours                         0
# Financial Stress                         0
# Family History of Mental Illness         0
# Depression                               0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
X = df.drop('Depression', axis=1)
y = df['Depression']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=45)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

# %%
labelencoder = LabelEncoder()
labelencoder1 = LabelEncoder()
labelencoder2= LabelEncoder()
labelencoder3 = LabelEncoder()
labelencoder4 = LabelEncoder()

# %%
X_train['Gender'] = labelencoder.fit_transform(X_train['Gender'])

# %%
X_train['City'] = labelencoder1.fit_transform(X_train['City'])
X_train['Degree'] = labelencoder2.fit_transform(X_train['Degree'])
X_train['Sleep Duration'] = labelencoder3.fit_transform(X_train['Sleep Duration'])
X_train['Family History of Mental Illness'] = labelencoder4.fit_transform(X_train['Family History of Mental Illness'])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print(df.columns)
# Out:
# Index(['id', 'Gender', 'Age', 'City', 'Profession', 'Academic Pressure',
#        'Work Pressure', 'CGPA', 'Study Satisfaction', 'Job Satisfaction',
#        'Sleep Duration', 'Dietary Habits', 'Degree',
#        'Have you ever had suicidal thoughts ?', 'Work/Study Hours',
#        'Financial Stress', 'Family History of Mental Illness', 'Depression'],
#       dtype='object')

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='Depression')
plt.title('Distribution of Depression Levels')
plt.xlabel('Depression Level')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x='Gender', y='Depression')
plt.title('Depression Levels by Gender')
plt.xlabel('Gender')
plt.ylabel('Depression Level')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data=df, x='Age', kde=True, bins=20)
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data=df, x='Work Pressure', kde=True, bins=20)
plt.title('Distribution of Work Pressure')
plt.xlabel('Work Pressure')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data=df, x='CGPA', kde=True, bins=20)
plt.title('Distribution of CGPA')
plt.xlabel('CGPA')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data=df, x='Study Satisfaction', kde=True, bins=20)
plt.title('Distribution of Study Satisfaction')
plt.xlabel('Study Satisfaction')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data=df, x='Job Satisfaction', kde=True, bins=20)
plt.title('Distribution of Job Satisfaction')
plt.xlabel('Job Satisfaction')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='Sleep Duration')
plt.title('Distribution of Sleep Duration')
plt.xlabel('Sleep Duration')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='Sleep Duration')
plt.title('Distribution of Sleep Duration')
plt.xlabel('Sleep Duration')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x='Depression', y='CGPA')
plt.title('CGPA Distribution by Depression Level')
plt.xlabel('Depression Level')
plt.ylabel('CGPA')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x='Depression', y='Academic Pressure')
plt.title('Academic Pressure by Depression Level')
plt.xlabel('Depression Level')
plt.ylabel('Academic Pressure')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x='Depression', y='Age')
plt.title('Age Distribution by Depression Level')
plt.xlabel('Depression Level')
plt.ylabel('Age')
plt.show()

# %%
numerical_features = ['Age', 'Academic Pressure', 'Work Pressure', 'CGPA', 'Study Satisfaction', 'Job Satisfaction']

correlation_matrix = df[numerical_features].corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", square=True)
plt.title('Correlation Matrix of Numerical Features')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='CGPA', y='Academic Pressure', hue='Depression')
plt.title('CGPA vs Academic Pressure (colored by Depression)')
plt.xlabel('CGPA')
plt.ylabel('Academic Pressure')
plt.legend(title='Depression')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='Study Satisfaction', y='Job Satisfaction', hue='Depression')
plt.title('Study vs Job Satisfaction (colored by Depression)')
plt.xlabel('Study Satisfaction')
plt.ylabel('Job Satisfaction')
plt.legend(title='Depression')
plt.show()

# %%
print(X.dtypes)
# Out:
# id                                         int64
# Gender                                    object
# Age                                      float64
# City                                      object
# Profession                                object
# Academic Pressure                          int64
# Work Pressure                              int64
# CGPA                                     float64
# Study Satisfaction                         int64
# Job Satisfaction                           int64
# Sleep Duration                            object
# Dietary Habits                            object
# Degree                                    object
# Have you ever had suicidal thoughts ?     object
# Work/Study Hours                         float64
# Financial Stress                         float64
# Family History of Mental Illness          object
# dtype: object

# %%
X_encoded = pd.get_dummies(X, drop_first=True)

# %%
from sklearn.linear_model import LogisticRegression
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=45)                                  

clf = LogisticRegression()
clf.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10096\2876415011.py in ?()
#       1 from sklearn.linear_model import LogisticRegression
#       2 X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=45)
#       3
#       4 clf = LogisticRegression()
# ----> 5 clf.fit(X_train,y_train)
#       6
#
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1469                 skip_parameter_validation=(
#    1470                     prefer_skip_nested_validation or global_skip_validation
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py in ?(self, X, y, sample_weight)
#    1219             _dtype = np.float64
# ...

# %%
X_encoded = pd.get_dummies(X_train, drop_first=True)

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
le = LabelEncoder()

# Encode the target variable
y_encoded = le.fit_transform(y)

# %%
from sklearn.model_selection import train_test_split

# Split the data
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y_encoded, test_size=0.3, random_state=45)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[199], line 4
#       1 from sklearn.model_selection import train_test_split
#       3 # Split the data
# ----> 4 X_train, X_test, y_train, y_test = train_test_split(X_encoded, y_encoded, test_size=0.3, random_state=45)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
# ...
